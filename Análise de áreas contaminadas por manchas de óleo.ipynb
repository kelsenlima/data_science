# %%
import pandas as pd
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Lendo o arquivo.
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/dataset/2020-03-19_LOCALIDADES_AFETADAS.xlsx')

# %%
# Visualizando os dados.
df.tail(30)
# Out:
#       geocodigo                      localidade  ... Hora cou
# 979     2407500              Ponta de Maracajaú  ...  NaN   1
# 980     3200607                      Santa Cruz  ...  NaN   1
# 981     2407500                       Maracajaú  ...  NaN   1
# 982     2706505         Praia do Carro Quebrado  ...  NaN   1
# 983     3200607                       Coqueiral  ...  NaN   1
# 984     2407500  Praia de Barra de Maxaranguape  ...  NaN   1
# 985     2706505    Praia do Morro de Camaragibe  ...  NaN   1
# 986     2407500                           Muriú  ...  NaN   1
# 987     2706505             Praia do Marceneiro  ...  NaN   1
# 988     3200607                Praia de Gramuté  ...  NaN   1
# 989     3200607                         Aracruz  ...  NaN   1
# 990     3200607                   Barra do Sahy  ...  NaN   1
# 991     3200607                         Aracruz  ...  NaN   1
# 992     2910602            Foz do Rio Inhampube  ...  NaN   1
# ...

# %%
# Corrigindo o valor do índice 417.
df['localidade']=df['localidade'].replace('PORTO SAUIPE','Porto Sauípe')

# %%
df.tail(30)
# Out:
#       geocodigo                      localidade  ... Hora cou
# 979     2407500              Ponta de Maracajaú  ...  NaN   1
# 980     3200607                      Santa Cruz  ...  NaN   1
# 981     2407500                       Maracajaú  ...  NaN   1
# 982     2706505         Praia do Carro Quebrado  ...  NaN   1
# 983     3200607                       Coqueiral  ...  NaN   1
# 984     2407500  Praia de Barra de Maxaranguape  ...  NaN   1
# 985     2706505    Praia do Morro de Camaragibe  ...  NaN   1
# 986     2407500                           Muriú  ...  NaN   1
# 987     2706505             Praia do Marceneiro  ...  NaN   1
# 988     3200607                Praia de Gramuté  ...  NaN   1
# 989     3200607                         Aracruz  ...  NaN   1
# 990     3200607                   Barra do Sahy  ...  NaN   1
# 991     3200607                         Aracruz  ...  NaN   1
# 992     2910602            Foz do Rio Inhampube  ...  NaN   1
# ...

# %%
# Selecionando as colunas do nosso interesse.
df = pd.DataFrame(df,columns=['localidade','municipio','Data_Avist','estado','Latitude','Longitude'])

# %%
# Visualizando os dados depois das transformações.
df.head()
# Out:
#                        localidade  ...         Longitude
# 0                 Praia do Caburé  ...  42° 37' 58.21" W
# 1             Praia de Guaxindiba  ...  39° 43' 54.42" W
# 2        São José da Coroa Grande  ...   35° 7' 56.56" W
# 3                    Abreu do Una  ...   35° 8' 6.848" W
# 4  Ilha do Delta do Jequitinhonha  ...  38° 51' 57.30" W
#
# [5 rows x 6 columns]

# %%
# Verificando se existem valores duplicados.
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1004    False
# 1005    False
# 1006    False
# 1007    False
# 1008    False
# Length: 1009, dtype: bool

# %%
# Número de Localidades.
df['localidade'].count()
# Out:
# 1005

# %%
# Número de Municípios.
df['municipio'].unique().shape[0]
# Out:
# 129

# %%
# Número de Estados.
df['estado'].nunique()
# Out:
# 11

# %%
# Analisando os tipos das colunas.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1009 entries, 0 to 1008
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   localidade  1005 non-null   object
#  1   municipio   1009 non-null   object
#  2   Data_Avist  1009 non-null   object
#  3   estado      1009 non-null   object
#  4   Latitude    1009 non-null   object
#  5   Longitude   1009 non-null   object
# dtypes: object(6)
# memory usage: 47.4+ KB

# %%
# Transformando a coluna 'Data_Avist' em datetime.
df['Data_Avist'] = df['Data_Avist'].astype('datetime64')

# %%
# Verificando se o tipo da coluna foi alterado.
df.dtypes
# Out:
# localidade            object
# municipio             object
# Data_Avist    datetime64[ns]
# estado                object
# Latitude              object
# Longitude             object
# dtype: object

# %%
# Definindo a coluna 'Data_Avist' como índice do DataFrame.
df.set_index('Data_Avist',inplace=True)

# %%
# Visualizando.
df.tail()
# Out:
#                 localidade  ...         Longitude
# Data_Avist                  ...
# 2019-12-04  Praia da Barra  ...  39° 44' 1.688" W
# 2020-01-26             NaN  ...  36° 49' 36.92" W
# 2020-01-26             NaN  ...  36° 48' 19.95" W
# 2020-01-26             NaN  ...  36° 47' 55.19" W
# 2020-01-27             NaN  ...  36° 41' 41.64" W
#
# [5 rows x 5 columns]

# %%
# Salvando os dados.
df.to_csv('/content/drive/MyDrive/Colab Notebooks/dataset/2020-03-19_LOCALIDADES_AFETADAS-rev01.xlsx')
